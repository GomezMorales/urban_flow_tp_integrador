# %% [markdown]
# # Trabajo Práctico Integrador

# %% [markdown]
# ## Urban Flow

# %% [markdown]
# ## Integrantes del grupo:
#
# * **Mariano Tejerina**
# * **Emiliano Quiroga**
# * **Leandro Bonifacio**
# * **Luis Gomez Morales**

# %% [markdown]
# ## Sprint 1

# %% [markdown]
# ## Consideraciones Generales e Importantes
#
# - Desarrollo base: Los puntos solicitados son la base del trabajo práctico. Es posible la ampliación sin restricciones del mismo.
#
# - Organización del Notebook:
#   - Agregar antes del ejercicio 01 una celda donde se importan todas librerías necesarias.
#
#   - Utilizar un título para cada celda y escribir cada funcionalidad en una celda con título. Tener en cuenta agrupar las funcionalidades afines.

# %% [markdown]
# ## Versionado y Trabajo en Equipo
#
# - La entrega puede entregarse en grupos de máximo 6 personas (mínimo 1 / máximo 6) y la defensa es individual. Los grupos deben mantenerse a lo largo del trabajo integrador.
#
# - Se debe considerar que es un trabajo en equipo y que cualquiera de los integrantes puede realizar modificaciones para cada día de trabajo.
#
# - Control de Versiones: Utilizar herramientas de versionado. Vincularlo por token a tu cuenta personal de versionado en la nube.
#
# - Colaboradores: Brindar acceso al repositorio a las siguientes cuentas:
#
#   - lcd-sa182@ugr.edu.ar
#
#   - fpasinato@ugr.edu.ar
#
# - Changelog: Cada ejercicio/punto del trabajo práctico es considerado como un día distinto de trabajo. Debe quedar constancia en un archivo CHANGELOG.md de los cambios generados cada día.
#
# - Agregar una variable llamada desactivar_git_push que solamente me permita desactivar los "git push".
#
# - El archivo README.md debe contener el sprint en el que nos encontramos y debe contener:
#   - El objetivo.
#   - La introducción y el contexto del sprint de trabajo.

# %% [markdown]
# ## Criterios de evaluación
#
# - Funcionalidad:
#
#   - El código debe ejecutar sin errores al ejecutar "Ejecutar todo" (Ctrl+F9).
#
#   - Se debe implementar la totalidad de las funcionalidades solicitadas.
#
#   - La lógica del programa debe ser correcta y consistente.
#
#   - Utilización de librerías acorde a los problemas a resolver.
#
#   - Recordar antes de entregar de validar el notebook con los siguientes pasos. Ir al menú Runtine/Ejecutar -> Restart session and run all/Reiniciar la sessión y ejecutar todo
#
# - Claridad y organización:
#
#   - El código debe estar bien organizado y dividido.
#
#   - Utilizar diferentes celdas de código para resolver cada solicitud/punto dentro de un ejercicio específico con su comentario "title" correspondiente a la solución implementada.
#
#   - Se deben utilizar nombres de variables que describan su contenido/función.
#
#   - Se debe agregar comentarios explicativos y necesarios según estandares.
#
#   - Todos los imports deben ubicarse en la primer celda de ejecución arriba de la descripción del "Ejercicio 01".
#
#   - No se admite la sentencia "git add ." para simplificar el traceo.
#
#   - No se admiten comentarios innecesarios dentro del código. Solo comentar funciones, clases, métodos y propiedades de clase.
#
# - Estilo y presentación:
#
#   - Se debe usar una indentación consistente y un formato de código adecuado.
#
#   - Se deben evitar comentarios redundantes o irrelevantes.
#
#   - Se debe presentar el código de forma ordenada y profesional.
#
#   - Se debe utilizar [type hints](https://docs.python.org/3/library/typing.html).
#
#   - Se deben utilizar comentarios según el [pep8](https://peps.python.org/pep-0008/).
#
# - Herramientas:
#
#   - Utilizar principalmente librerías vistas durante la cursada. No se admiten librerías similares a las vistas en la materia.
#
#   - Utilizar librerías extras con criterios fundamentados, es decir, no utilizar por utilizar.
#
#   - Indentar a 2 espacios y cortar a 80 caracteres según estandares.
#
#   - No se puede utilizar gdrive.
#
#   - No se pueden utilizar herramientas alternativas a las vistas durante la cursada.

# %% [markdown]
# ## Condiciones de Entrega
# - Formato de Archivo: Los estudiantes deberán enviar un archivo con extensión .ipynb.
#
# - Nomenclatura: El nombre original del archivo debe reemplazar los valores indicados. Ejemplo: 0X_Price_Manager-Apellidos_Nombres.ipynb.
#
# - Estado de la entrega:
#   - Deberá entregarse ejecutado y con los datos precargados.
#   - Deberá entregarse el desarrollo sobre una copia de la plantilla original.
#
# - Canal de Entrega: La entrega se realiza en el aula virtual y solo se aceptan archivos (cualquier otra forma se considerará inválida). Solo se recibirán trabajos por correo adjunto a lcd-sa182@ugr.edu.ar si el plazo en la plataforma ha finalizado. No se aceptarán enlaces sueltos.

# %% [markdown]
# ## Recomendaciones y Consecuencias del Incumplimiento
# - Recomendaciones: Comenzar a trabajar con suficiente antelación. Leer y comprender el enunciado en su totalidad. Realizar consultas ante dudas al correo: lcd-sa182@ugr.edu.ar o fpasinato@ugr.edu.ar. La entrega en tiempo y forma es fundamental.
#
# - Incumplimiento: Los trabajos que no cumplan con los requisitos no serán tomados en cuenta como nota final. Solo serán corregidos y evaluados con nota para la devolución correspondiente. Se considera incumplimiento a:
#
#   - Entregas fuera de término.
#
#   - Trabajos que no se entreguen sobre la plantilla de trabajo estipulada.
#
#   - Trabajos que no se ejecuten completos (que contengan errores intermedios al dar "Ejecutar todo").

# %% [markdown]
# ---

# %% [markdown]
# ## Objetivo
#
# El objetivo principal de este proyecto es aplicar los conocimientos adquiridos en para el versionado de código, la organización, limpieza del código y la utilización de pandas.

# %% [markdown]
# ## Introducción y Contexto del problema

# %% [markdown]
# ### Sprint 1
#
# La localidad llamada Vaalserberg de Bélgica se encuentra en la zona fronteriza y limita con los paises de Países Bajos y Alemania. Esta localidad cuenta con un sistema de radares urbanos para la detección de infracciones por exceso de velocidad. Los registros históricos provienen de sistemas heredados, el cuál presenta errores de formato, faltante de datos generando registros inconsistentes en el nuevo sistema.
#
# Debemos analizar y depurar los datos de viejo sistema para obtener información relevante sobre las infracciones y de está forma en el futuro poder incorporar los datos al nuevo sistema sin inconsistencias.
#
# Descargar el dataset [speeding fines](https://raw.githubusercontent.com/HAD141/datasets/refs/heads/main/TrabajosPracticos/urban_flow/speeding_fines.csv) https://raw.githubusercontent.com/HAD141/datasets/refs/heads/main/TrabajosPracticos/urban_flow/speeding_fines.csv
#
# El dataset contiene información histórica de multas por exceso de velocidad y presenta errores que deberán ser tratados para evitar inconsistencias.

# %% [markdown]
# ---

# %%
# Título: Importación de librerías y configuración global
# %pip install pandas requests matplotlib seaborn

import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from typing import List, Optional, Dict, Any

desactivar_git_push: bool = False

print("Librerías cargadas exitosamente y configuración inicial completa.")
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Librerías cargadas exitosamente y configuración inicial completa.

# %%
URL_FINES: str = (
  "https://raw.githubusercontent.com/HAD141/datasets/refs/heads/main/"
  "TrabajosPracticos/urban_flow/speeding_fines.csv"
)
PATH_RAW: str = "urban_flow/data/raw/speeding_fines.csv"
PATH_INTERIM = "urban_flow/data/interim"

# %% [markdown]
# ## Ejercicio 01
#
# > Puntos: 1
#
# Inicialización y configuración de la herramienta de versionado. Vamos a trabajar sobre la rama llamada "Sprint_1".
#
# La estructura de directorios es:
#
# ```
# ├── urban_flow
# │   ├── data
# │   │   ├── interim (almacena dataset procesados de pasos intermedios)
# │   │   │   ├── plots
# │   │   ├── processed (almacena dataset procesados finales para entregar a otra aplicación)
# │   │   ├── raw (almacena los dataset en crudo, sin procesar)
# ```

# %%
# Título: Configuración del entorno de ejecución (Colab o Local)

import os

if 'google.colab' in str(get_ipython()):
  repo_url = "https://github.com/GomezMorales/urban_flow_tp_integrador.git"
  repo_name = "urban_flow_tp_integrador"
  
  if not os.path.exists(repo_name):
    print("Entorno Colab detectado. Clonando repositorio...")
    # !git clone -b Sprint_1 {repo_url}
  
  # %cd {repo_name}
  
  print(f"\nDirectorio actual: {os.getcwd()}")
else:
  print(f"Entorno local/Codespaces detectado. Directorio actual: {os.getcwd()}")
# Out:
# Entorno local/Codespaces detectado. Directorio actual: /workspaces/urban_flow_tp_integrador

# %% [markdown]
# ## Ejercicio 02
#
# > Puntos: 1
#
# Los desarrollos que deben realizar son:
#
# - Descargar el dataset raw original y almacenarlo en `urban_flow/data/raw`.
#
# - Mostrar las 5 primeras filas.
#
# - Analizar tipos de datos
#
# - Contar los valores nulos.

# %%
# Título: Carga y verificación del dataset original (Ejercicio 02)

def gestionar_dataset(url: str, ruta_local: str) -> pd.DataFrame:
  """
  Verifica la existencia del archivo localmente; si no existe, lo descarga.
  Retorna el DataFrame cargado.
  """
  if not os.path.exists(ruta_local):
    print(f"Archivo no encontrado en {ruta_local}. Iniciando descarga...")
    respuesta = requests.get(url)
    respuesta.raise_for_status()
    with open(ruta_local, 'wb') as f:
      f.write(respuesta.content)
    print("Descarga completada.")
  else:
    print(f"El archivo ya existe en {ruta_local}. Cargando datos locales...")
  
  return pd.read_csv(ruta_local)


df_original: pd.DataFrame = gestionar_dataset(URL_FINES, PATH_RAW)

print("\n--- 5 primeras filas ---")
display(df_original.head())

print("\n--- Análisis de tipos de datos ---")
print(df_original.dtypes)

print("\n--- Conteo de valores nulos ---")
print(df_original.isnull().sum())
# Out:
# El archivo ya existe en urban_flow/data/raw/speeding_fines.csv. Cargando datos locales...
#
# --- 5 primeras filas ---
#    multa_id    patente         fecha          hora  velocidad_registrada  \
# 0         1    FD 1475    24/09/2021      09:01 AM                   NaN
# 1         2   0695 DVH    19/05/2020         18:01                   NaN
# 2         3   WU 341 A    2022/07/17      09:01 AM                 107.0
# 3         4   GN64 OTP  invalid_date  invalid_hour                   NaN
# 4         5  BX 55 DOG    2021/01/21  invalid_hour                  94.0
#
#    velocidad_maxima         ubicacion radar_id estado_multa
# 0                60  Av. Siempre Viva      R01      APELADA
# 1                40   Av Siempre Viva      NaN      APELADA
# 2                60     AV LIBERTADOR      R03       PAGADA
# 3                60            Ruta 9      NaN      APELADA
# 4                60  Av. Siempre Viva      NaN        ERROR
# --- Análisis de tipos de datos ---
# multa_id                  int64
# patente                     str
# fecha                       str
# hora                        str
# velocidad_registrada    float64
# velocidad_maxima          int64
# ubicacion                   str
# radar_id                    str
# estado_multa                str
# dtype: object
#
# --- Conteo de valores nulos ---
# multa_id                   0
# patente                   50
# fecha                      0
# hora                       0
# velocidad_registrada    1957
# velocidad_maxima           0
# ubicacion                  0
# radar_id                1002
# estado_multa               0
# dtype: int64

# %% [markdown]
# ## Ejercicio 03
#
# > Puntos: 2
#
# Utilizando Pandas:
#
# - Normalizar las de fechas con el formato 'YYYY-MM-DD', en caso de fechas inválidas completar con la fecha `1932-01-01`. Mostrar las 10 primeras fechas.
#
# - Normalizar los horas al formato de 24hs, las horas inválidas se procesaran como `00:00`. Mostrar las 10 primeras horas.
#
# - Normalizar las ubicaciones. Quitar caracteres especiales y pasar todo a mayúsculas. Mostrar las 10 primeras ubicaciones.
#
# - Limpiar y normalizar las patentes, en caso de error completar con pd.NA (no disponible/not available). Quitar caracteres especiales y pasar todo a mayúsculas. Mostrar las 10 últimas patentes.
#
# - Eliminar las filas que posean valores relevantes para las multas y que se encuentren vacios. Mostrar la cantidad de registros eliminados y cuales son las columnas que se observaron utilizando la leyenda
# ```
# Se eliminaron X filas.
# Las columnas observadas son:
#  - XXX
#  - XXX
#  - ...
# ```
#
# - Detectar y eliminar los outliers. Mostrar la cantidad de registros eliminados y cuales son las columnas que se observaron utilizando la leyenda
# ```
# Se eliminaron X filas.
# Las columnas observadas son:
#  - XXX
#  - XXX
#  - ...
# ```
#
# - Crear la columna `exceso_velocidad_real` y calcularla. El exceso de velocidad real es la diferencia entre velocidad_registrada y la velocidad_maxima. Mostrar las primeras 10 patentes y su exceso de velocidad real.
#
# - Crear la columna `exceso_velocidad` y calcularla. El exceso de velocidad es la diferencia entre velocidad_registrada y la velocidad_maxima más un 5 porciento de la velocidad máxima. Mostrar las primeras 10 patentes y su exceso de velocidad.
#
# - Eliminar las filas que no cometieron infracciones según el exceso de velocidad.Mostrar cuantas filas se eliminaron con la leyenda
# ```
# Se eliminaron X filas.
# ```
#
# - Guardar el dataset limpio en `urban_flow/data/interim/speeding_fines.csv`

# %% [markdown]
# ### Normalización

# %% [markdown]
# #### Normalización campo "patente"

# %%
#Para tratar las patentes, primero creo una columna llamada "patente_clean",
# normalizo a mayúsculas todas las patentes
df_original['patente_clean'] = df_original['patente'].str.upper()

#Realizo los siguientes replaces:
# Quito los espacios (usando regex para ser más robusto con cualquier tipo 
# de espacio)
# Quito los guiones
# Convierto el valor interpretable nulo "INVALID_PLATE" por NaN

#Por último, fuerzo que el campo sea considerado un string nullable, preservando pd.NA.
df_original['patente_clean'] = df_original['patente_clean'].str\
.strip()\
.replace(r'\s+', '', regex=True)\
.str.replace('-', '', regex=False)\
.replace('INVALID_PLATE', pd.NA)\
.astype(pd.StringDtype())

# %% [markdown]
# #### Normalización campo "fecha"

# %%
# Limpieza del campo fecha
# 1. Convierte 'fecha' a minúsculas, elimina espacios en blanco y reemplaza
# '/' con '-' para un formato consistente.
# 2. Asigna el resultado a 'fecha_clean' para usarla como columna auxiliar.
df_original['fecha_clean'] = df_original['fecha'].str.lower().str.strip().str.replace('/', '-', regex=False)
# 3. Reemplaza la cadena específica 'invalid_date' con pd.NaT para que pd.to_datetime pueda manejarla como un valor faltante.
df_original['fecha_clean'] = df_original['fecha_clean'].replace('invalid_date', pd.NaT)

# Intenta parsear fechas con dayfirst=True (ej., 'dd-mm-yyyy')
parsed_dayfirst = pd.to_datetime(df_original['fecha_clean'], errors='coerce', dayfirst=True)

# Intenta parsear fechas con formato año-primero (ej., 'yyyy-mm-dd')
parsed_yearfirst = pd.to_datetime(df_original['fecha_clean'], errors='coerce', format='%Y-%m-%d')

# Combina las series parseadas: Prioriza day-first, luego year-first.
# Si parsed_dayfirst devuelve NaT, intenta parsed_yearfirst y asigna el resultado a 'fecha_clean'.
df_original['fecha_clean'] = parsed_dayfirst.fillna(parsed_yearfirst)

# Finalmente, reemplaza cualquier valor NaT restante (aquellos que fallaron 
# en todos los intentos de parseo) con un objeto datetime para '1932-01-01'
df_original['fecha_clean'] = df_original['fecha_clean'].fillna(pd.to_datetime('1932-01-01'))

# %% [markdown]
# #### Normalización campo "hora"

# %%
#Normalizo a mayúsculas AM/PM para hacer la conversión y normalizo el valor
# inválido que utiliza el df ("invalid_hour") para que sea mas sencillo
# cambiarlo a NaN.
df_original['hora_clean'] = df_original['hora'].str.lower().replace('invalid_hour', pd.NA)

#Convierto primero las horas en formato 24hs
parsed_24h = pd.to_datetime(df_original['hora_clean'], format='%H:%M', errors='coerce').dt.time

#Convierto las horas que este en formato AM/PM
parsed_12h = pd.to_datetime(df_original['hora_clean'].str.upper(), format='%I:%M %p', errors='coerce').dt.time

#En este paso creo una nueva columna "hora_clean" y ahi guardo las horas
# casteadas, para ello combino parsed_24 contra parsed_12 donde si el 
# primero tiene un valor válido coloca ese, si encuentra un NaT (Not a Time)
# lo rellena con el valor equivalente en parsed_12h

df_original['hora_clean'] = parsed_24h.fillna(parsed_12h)

#Paso final, aplico un lambda a la columna "hora_clean" para que aplique la
# conversión al formato deseado (HH:MM), los valores inválidos son
# transformados a '00:00'
df_original['hora_clean'] = df_original['hora_clean'].apply(lambda x: x.strftime('%H:%M') if pd.notna(x) else '00:00')

# %% [markdown]
# #### Normalización campo "ubicación"

# %%
#Normalizo primero a mayúsculas las direcciones, luego quito espacios que
# puedan existir a izquierda y derecha de la cadena

#Normalizo mediante regex la variación de tipeo en AV
# El primer regex "^\s*AV\." va a tomar todos los espacios (si existiesen)
#  junto a "AV." y los va a reemplazar por "AV "
# El segundo regex "\s+" va a tomar la multiple existencia de espacios y los 
# va a reemplazar por un único espacio



df_original['ubicacion_clean'] = df_original['ubicacion'].str\
  .upper()\
  .str.strip()\
  .replace(r'^\s*AV\.','AV ',regex=True)\
  .replace(r'\s+', ' ', regex=True)\
  .astype(str)

# %% [markdown]
# ### Asignar las columnas normalizadas a las originales para que quede listo el dataset

# %%
df_original['fecha'] = df_original['fecha_clean']
df_original['hora'] = df_original['hora_clean']
df_original['ubicacion'] = df_original['ubicacion_clean']
df_original['patente'] = df_original['patente_clean']

#Elimino las columnas *_clean que sirvieron para la normalización de la
# información
df_original = df_original.drop(columns=['fecha_clean', 'hora_clean', 'ubicacion_clean','patente_clean'])

# %% [markdown]
# ### Muestra de datos

# %% [markdown]
# #### Mostrar las 10 primeras fechas

# %%
df_original['fecha'].head(10)
# Out:
# 0   2021-09-24
# 1   2020-05-19
# 2   2022-07-17
# 3   1932-01-01
# 4   2021-01-21
# 5   2023-07-27
# 6   2023-06-16
# 7   2023-01-11
# 8   1932-01-01
# 9   1932-01-01
# Name: fecha, dtype: datetime64[us]

# %% [markdown]
# #### Mostrar las 10 primeras horas

# %%
df_original['hora'].head(10)
# Out:
# 0    09:01
# 1    18:01
# 2    09:01
# 3    00:00
# 4    00:00
# 5    00:00
# 6    18:01
# 7    08:01
# 8    09:01
# 9    14:01
# Name: hora, dtype: str

# %% [markdown]
# #### Mostrar las 10 primeras ubicaciones

# %%
df_original['ubicacion'].head(10)
# Out:
# 0    AV SIEMPRE VIVA
# 1    AV SIEMPRE VIVA
# 2      AV LIBERTADOR
# 3             RUTA 9
# 4    AV SIEMPRE VIVA
# 5    AV SIEMPRE VIVA
# 6      AV LIBERTADOR
# 7    AV SIEMPRE VIVA
# 8    AV SIEMPRE VIVA
# 9      AV LIBERTADOR
# Name: ubicacion, dtype: str

# %% [markdown]
# #### Mostrar las 10 primeras patentes

# %%
df_original['patente'].head(10)
# Out:
# 0     FD1475
# 1    0695DVH
# 2     WU341A
# 3    GN64OTP
# 4    BX55DOG
# 5       <NA>
# 6    CD05601
# 7      BP717
# 8     41RSTZ
# 9    OUTSTDN
# Name: patente, dtype: string

# %% [markdown]
# ### Eliminación de inconsistencias y valores erróneos

# %% [markdown]
# #### Limpieza del dataset, volcando el resultado en un dataset temporal

# %%
conditions = (
    (df_original['patente'].isna()) |\
    (df_original['velocidad_registrada'].isna()))

rows_before_cleaning = df_original.shape[0]

# La condición para las filas que SÍ queremos mantener (las "limpias")
# Es decir, que NO tengan velocidad nula o que la patente no sea nula.

clean_data_condition = ~(conditions)

df_cleaned = df_original[clean_data_condition]

rows_after_cleaning = df_cleaned.shape[0]

rows_eliminated_cleaning = rows_before_cleaning - rows_after_cleaning

print(f"Filas antes de la limpieza: {rows_before_cleaning}")
print(f"Filas después de la limpieza: {rows_after_cleaning}")
print(f"Cantidad de filas eliminadas en la limpieza: {rows_eliminated_cleaning}")
print("""Las columnas observadas son:
 - velocidad_registrada
 - patente
""")
# Out:
# Filas antes de la limpieza: 4000
# Filas después de la limpieza: 2018
# Cantidad de filas eliminadas en la limpieza: 1982
# Las columnas observadas son:
#  - velocidad_registrada
#  - patente

# %% [markdown]
# #### Sobreescritura del dataset original por el dataset limpio

# %%
df_original = df_cleaned

print("Primeras 5 filas del dataset limpio")
df_original.head(5)
# Out:
# Primeras 5 filas del dataset limpio
#     multa_id  patente      fecha   hora  velocidad_registrada  \
# 2          3   WU341A 2022-07-17  09:01                 107.0
# 4          5  BX55DOG 2021-01-21  00:00                  94.0
# 7          8    BP717 2023-01-11  08:01                  70.0
# 9         10  OUTSTDN 1932-01-01  14:01                  71.0
# 11        12  TL03GOG 2022-07-21  09:01                  38.0
#
#     velocidad_maxima        ubicacion radar_id estado_multa
# 2                 60    AV LIBERTADOR      R03       PAGADA
# 4                 60  AV SIEMPRE VIVA      NaN        ERROR
# 7                 60  AV SIEMPRE VIVA      R01       PAGADA
# 9                 40    AV LIBERTADOR      R02      APELADA
# 11                40  AV SIEMPRE VIVA      R02       PAGADA

# %% [markdown]
# ### Detección y eliminación de Outliers

# %%
def remove_outliers_iqr(df: pd.DataFrame, columns: List[str]) -> pd.DataFrame:
  """
  Elimina outliers de un DataFrame usando el método IQR para las columnas especificadas.

  Args:
    df (pd.DataFrame): El DataFrame de entrada.
    columns (List[str]): Lista de nombres de columnas numéricas a procesar.

  Returns:
    pd.DataFrame: El DataFrame sin outliers.
    int: Cantidad de filas eliminadas.
  """
  initial_rows = df.shape[0]
  df_cleaned_outliers = df.copy()
  # Usaremos un conjunto para asegurar que solo se elimine una vez por cada fila que sea outlier en MÚLTIPLES columnas
  outlier_indices = set()
  cols_with_outliers_detected = [] # Renombrado para evitar confusión con el parámetro 'columns'

  for col in columns:
    if col in df_cleaned_outliers.columns and pd.api.types.is_numeric_dtype(df_cleaned_outliers[col]):
      Q1 = df_cleaned_outliers[col].quantile(0.25)
      Q3 = df_cleaned_outliers[col].quantile(0.75)
      IQR = Q3 - Q1
      lower_bound = Q1 - 1.5 * IQR
      upper_bound = Q3 + 1.5 * IQR

      # Identificar outliers por índice
      col_outliers = df_cleaned_outliers[(df_cleaned_outliers[col] < lower_bound) | (df_cleaned_outliers[col] > upper_bound)].index

      if not col_outliers.empty:
        cols_with_outliers_detected.append(col)
        outlier_indices.update(col_outliers.tolist())

  if outlier_indices:
    df_cleaned_outliers = df_cleaned_outliers.drop(index=list(outlier_indices))

  final_rows = df_cleaned_outliers.shape[0]
  removed_count = initial_rows - final_rows

  print(f"Se eliminaron {removed_count} filas.")
  print("Las columnas observadas son:")
  print("\n".join(f"- {column}" for column in columns))

  return df_cleaned_outliers


#Aplicación de la función al dataset
columns_to_check_outliers = ['velocidad_registrada']
df_original = remove_outliers_iqr(df_original.copy(),columns_to_check_outliers)
# Out:
# Se eliminaron 0 filas.
# Las columnas observadas son:
# - velocidad_registrada

# %% [markdown]
# ### Columnas calculadas

# %% [markdown]
# #### Cálculo columna exceso_velocidad_real

# %%
#Se crea una columna nueva donde se calcula la velocidad capturada menos la 
# velocidad capturada para determinar el exceso de velocidad. Aquellos registros
# que no presentaron excesos su valor sera inferior a 0.
df_original['exceso_velocidad_real'] = df_original['velocidad_registrada'] - df_original['velocidad_maxima']

#Muestros las 10 primeras patentes y su exceso de velocidad real
df_original[['patente','exceso_velocidad_real']].head(10)
# Out:
#     patente  exceso_velocidad_real
# 2    WU341A                   47.0
# 4   BX55DOG                   34.0
# 7     BP717                   10.0
# 9   OUTSTDN                   31.0
# 11  TL03GOG                   -2.0
# 12   GE1466                   35.0
# 16  5777770                   53.0
# 20  BHRP770                   11.0
# 21   RFH373                   41.0
# 23   XIIUME                   12.0

# %% [markdown]
# #### Cálculo columna exceso_velocidad

# %%
#Se cálcula una columna adicional, partiendo de 'exceso_velocidad_real' 
# la fórmula es: (velocidad_registrada - velocidad_maxima) + (0.05 * velocidad_maxima)
df_original['exceso_velocidad'] = df_original['velocidad_registrada'] - (df_original['velocidad_maxima'] * 1.05)

#Muestro las 10 primeras patentes y su exceso de velocidad
df_original[['patente','exceso_velocidad']].head(10)
# Out:
#     patente  exceso_velocidad
# 2    WU341A              44.0
# 4   BX55DOG              31.0
# 7     BP717               7.0
# 9   OUTSTDN              29.0
# 11  TL03GOG              -4.0
# 12   GE1466              33.0
# 16  5777770              51.0
# 20  BHRP770               8.0
# 21   RFH373              37.0
# 23   XIIUME              10.0

# %% [markdown]
# ### Limpieza de filas en donde no se cometió exceso de velocidad

# %%
#Capturo la cantidad de filas antes de la limpieza
rows_before_maxspeed_clean = df_original.shape[0]
#Filtro el dataset quedandome solamente con los excesos de velocidad válidos
df_original = df_original[df_original['exceso_velocidad'] > 0]

rows_after_maxspeed_clean = df_original.shape[0]

#Cantidad de filas afectadas por la limpieza
rows_eliminated_maxspeed_clean = rows_before_maxspeed_clean - rows_after_maxspeed_clean

print(f"Se eliminaron {rows_eliminated_maxspeed_clean} filas.")
# Out:
# Se eliminaron 305 filas.

# %% [markdown]
# ### Guardado del dataset limpio en interim

# %%
df_original.to_csv(PATH_INTERIM + '/speeding_fines.csv', index=False)

# %% [markdown]
# ## Ejercicio 04
#
# > Puntos: 2
#
# Definir una clase FineAnalyzer que cumpla con las siguientes funcionalidades:
#
# - Reciba el DataFrame limpio como argumento de inicialización.
#
# - Encapsule correctamente los datos.
#
# - Implemente métodos para:
#
#   - Ranking de las patentes más multadas (top 5). Debe retornar un DataFrame ordenado de mayor a menor y el índice debe comenzar desde 1, con las columnas de patentes y cantidad..
#
#   - Ranking de los horarios donde se producen más multas (top 5). Debe retornar un DataFrame ordenado de mayor a menor y el índice debe comenzar desde 1, con las columnas de hora y cantidad.
#
#
#   - Exceso promedio de velocidad. Debe retorna un flotante.
#
#   - Exceso real promedio de velocidad . Debe retorna un flotante.
#
#   - Contabilizar la cantidad de multas por cada  ubicación. Debe retornar un DataFrame ordenado por ubicación mostrando la ubicación y la cantidad.
#
# - Crear el objecto e invocar cada uno de los métodos en celdas separadas.

# %%
class FineAnalyzer:
    """Clase para analizar datos de multas de tránsito."""

    def __init__(self, df: pd.DataFrame) -> None:
        """
        Inicializa el analizador con una copia del DataFrame original.

        Args:
            df: DataFrame con la información de las multas.
        """
        self._df = df.copy()

    def ranking_patentes(self) -> pd.DataFrame:
        """
        Obtiene las 5 patentes con mayor cantidad de infracciones.

        Returns:
            DataFrame con el ranking de patentes y sus cantidades.
        """
        if "patente" not in self._df.columns:
            raise ValueError("La columna 'patente' no existe en el DataFrame.")

        ranking = (
            self._df["patente"]
            .value_counts()
            .head(5)
            .reset_index()
        )
        ranking.index = ranking.index + 1
        ranking.columns = ["patente", "cantidad"]
        return ranking

    def ranking_horarios(self) -> pd.DataFrame:
        """
        Identifica los 5 horarios con mayor frecuencia de multas.

        Returns:
            DataFrame con el ranking de horas y sus cantidades.
        """
        if "hora" not in self._df.columns:
            raise ValueError("La columna 'hora' no existe en el DataFrame.")

        ranking = (
            self._df["hora"]
            .value_counts()
            .head(5)
            .reset_index()
        )
        ranking.index = ranking.index + 1
        ranking.columns = ["hora", "cantidad"]
        return ranking

    def exceso_promedio(self) -> float:
        """
        Calcula el promedio general del exceso de velocidad.

        Returns:
            Valor decimal del promedio.
        """
        if "exceso_velocidad" not in self._df.columns:
            raise ValueError("Falta la columna 'exceso_velocidad'.")

        return float(self._df["exceso_velocidad"].mean())

    def exceso_real_promedio(self) -> float:
        """
        Calcula el promedio del exceso de velocidad real.

        Returns:
            Valor decimal del promedio real.
        """
        if "exceso_velocidad_real" not in self._df.columns:
            raise ValueError("Falta la columna 'exceso_velocidad_real'.")

        return float(self._df["exceso_velocidad_real"].mean())

    def multas_por_ubicacion(self) -> pd.DataFrame:
        """
        Contabiliza el total de multas agrupadas por ubicación.

        Returns:
            DataFrame con la ubicación y su respectiva cantidad.
        """
        if "ubicacion" not in self._df.columns:
            raise ValueError("La columna 'ubicacion' no existe en el DataFrame.")

        ubic = (
            self._df["ubicacion"]
            .value_counts()
            .reset_index()
        )
        ubic.columns = ["ubicacion", "cantidad"]
        return ubic

# %% [markdown]
# ## Crear el objecto e invocar cada uno de los métodos en celdas separadas.

# %%
analyzer = FineAnalyzer(df_original)

# %% [markdown]
# ## Ranking de las patentes más multadas

# %%
analyzer.ranking_patentes()
# Out:
#   patente  cantidad
# 1  WEFLYN        38
# 2  HF3461        37
# 3   T0YDR        36
# 4  M431ZW        34
# 5  AWS167        33

# %% [markdown]
# ## Ranking de los horarios donde se producen más multas

# %%
analyzer.ranking_horarios()
# Out:
#     hora  cantidad
# 1  00:00       339
# 2  09:04         9
# 3  09:20         8
# 4  09:23         8
# 5  10:31         8

# %% [markdown]
# ## Exceso promedio de velocidad

# %%
analyzer.exceso_promedio()
# Out:
# 39.318155283129016

# %% [markdown]
# ## Exceso real promedio de velocidad

# %%
analyzer.exceso_real_promedio()
# Out:
# 42.345008756567424

# %% [markdown]
# ## Cantidad de multas por cada ubicación

# %%
analyzer.multas_por_ubicacion()
# Out:
#          ubicacion  cantidad
# 0    AV LIBERTADOR       708
# 1  AV SIEMPRE VIVA       512
# 2           RUTA 9       493

# %% [markdown]
# ## Punto 05
#
# > Puntos: 2
#
#
# Responder a cada punto con un gráfico.
#
# - Ranking de las 10 patentes más reincidentes ordenadas de mayor a menor. Exportar el gráfico con el nombre `ubran_flow/data/interim/plots/fines.jpg`
#
#
# - Mostrar el porcentaje de infracciones por hora en un gráfico de torta. Exportar el gráfico con el nombre `ubran_flow/data/interim/plots/hours.jpg`
#
# - Mostrar la cantidad de infracciones por mes en un gráfico de barras horizontal ordenado de mayor a menor. Exportar el gráfico con el nombre `ubran_flow/data/interim/plots/months.jpg`
#
# - Mostrar en un gráfico de líneas de los excesos de velocidad agrupados por la hora 00:00. Exportar el gráfico con el nombre `ubran_flow/data/interim/plots/hour.jpg`
#
# - Mostrar en un gráfico de líneas de los excesos de velocidad agrupados por la fecha 1932-01-01. Exportar el gráfico con el nombre `ubran_flow/data/interim/plots/date.jpg`

# %%
# Cargo el dataset limpio para crear los gráficos
df = pd.read_csv("urban_flow/data/interim/speeding_fines.csv")

def guardar_grafico(ruta: str) -> None:
  """Guarda y muestra el gráfico actual."""
  plt.tight_layout()
  plt.savefig(ruta)
  plt.show()

# %%
# Top 10 patentes más reincidentes

top_patentes = (
  df["patente"]
  .value_counts()
  .head(10)
)

figura = plt.figure(dpi=100)
plt.bar(top_patentes.index, top_patentes.values, color="steelblue")
plt.title("Top 10 patentes más reincidentes")
plt.xlabel("Patente")
plt.ylabel("Cantidad de multas")
plt.xticks(rotation=45)
guardar_grafico("urban_flow/data/interim/plots/fines.jpg")

# %%
# Porcentaje de infracciones por hora

infracciones_hora = (
  df["hora"]
  .str.split(":")
  .str[0]
  .value_counts()
  .sort_index()
)

etiquetas = [f"{h}:00 hs" for h in infracciones_hora.index]

figura = plt.figure(dpi=100)
colores = plt.cm.tab20(np.linspace(0, 1, len(infracciones_hora)))
plt.pie(
  infracciones_hora.values,
  labels=etiquetas,
  autopct="%1.1f%%",
  colors=colores
)
plt.title("Porcentaje de infracciones por hora")
guardar_grafico("urban_flow/data/interim/plots/hours.jpg")

# %%
# Cantidad de infracciones por mes

# Mapeo el número de mes con el nombre
meses = {
  1: "Enero", 2: "Febrero", 3: "Marzo",
  4: "Abril", 5: "Mayo", 6: "Junio",
  7: "Julio", 8: "Agosto", 9: "Septiembre",
  10: "Octubre", 11: "Noviembre", 12: "Diciembre"
}

infracciones_mes = (
  pd.to_datetime(df["fecha"])
  .dt.month
  .value_counts()
  .sort_values(ascending=True)
)

etiquetas = [meses[m] for m in infracciones_mes.index]

figura = plt.figure(dpi=100)
plt.barh(etiquetas, infracciones_mes.values, color="steelblue")
plt.title("Cantidad de infracciones por mes")
plt.xlabel("Cantidad de multas")
plt.ylabel("Mes")
guardar_grafico("urban_flow/data/interim/plots/months.jpg")

# %%
# Excesos de velocidad agrupados por hora 00:00

excesos_hora = (
  df[df["hora"] == "00:00"]["exceso_velocidad"]
  .reset_index(drop=True)
)

figura = plt.figure(dpi=100)
plt.plot(excesos_hora, color="steelblue")
plt.title("Excesos de velocidad agrupados por hora 00:00")
plt.xlabel("Infracción")
plt.ylabel("Exceso de velocidad")
guardar_grafico("urban_flow/data/interim/plots/hour.jpg")

# %%
# Excesos de velocidad agrupados por fecha 1932-01-01

excesos_fecha = (
  df[df["fecha"] == "1932-01-01"]["exceso_velocidad"]
  .reset_index(drop=True)
)

figura = plt.figure(dpi=100)
plt.plot(excesos_fecha, color="steelblue")
plt.title("Excesos de velocidad agrupados por fecha 1932-01-01")
plt.xlabel("Infracción")
plt.ylabel("Exceso de velocidad")
guardar_grafico("urban_flow/data/interim/plots/date.jpg")

# %% [markdown]
# ## Punto 06
#
# > Puntos: 1
#
# - Mostrar el porcentaje de infracción que se produjeron en la fecha 1932-01-01.
#
# ```
# El porcentaje de infracciones en la fecha 1932-01-01 es XX.XX%
# ```
#
# - Mostrar el porcentaje de infracción que se produjeron en la hora 00:00.
# ```
# El porcentaje de infracciones a la hora 00:00 es XX.XX%
# ```

# %%
# Título: Porcentaje de infracciones en la fecha 1932-01-01

total_infracciones: int = len(df)
infracciones_fecha_sentinel: int = len(df[df["fecha"] == "1932-01-01"])
porcentaje_fecha: float = (infracciones_fecha_sentinel / total_infracciones) * 100

print(f"El porcentaje de infracciones en la fecha 1932-01-01 es {porcentaje_fecha:.2f}%")
# Out:
# El porcentaje de infracciones en la fecha 1932-01-01 es 26.44%

# %%
# Título: Porcentaje de infracciones a la hora 00:00

infracciones_hora_sentinel: int = len(df[df["hora"] == "00:00"])
porcentaje_hora: float = (infracciones_hora_sentinel / total_infracciones) * 100

print(f"El porcentaje de infracciones a la hora 00:00 es {porcentaje_hora:.2f}%")
# Out:
# El porcentaje de infracciones a la hora 00:00 es 19.79%

# %% [markdown]
# ## Punto 07
#
# > Puntos: 1
#
#
#
# Redactar una conclusión acerca de los datos que contiene el dataset.

# %%
# %%writefile -a README.md
#
# ## Conclusiones del dataset — Sprint 1
#
# El dataset de multas por exceso de velocidad de Vaalserberg presentó
# inconsistencias significativas heredadas del sistema anterior.
#
# Tras el proceso de limpieza y normalización se identificaron los
# siguientes hallazgos:
#
# - **Datos con fecha inválida (1932-01-01):** un porcentaje de los
#   registros no poseía una fecha válida. Esto indica fallas en el
#   sistema de registro del radar o en la exportación del sistema
#   heredado.
#
# - **Datos con hora inválida (00:00):** de manera similar, una
#   proporción de registros carecía de hora válida, lo que impide
#   analizar con precisión los horarios de mayor incidencia para
#   esos casos.
#
# - **Patentes inválidas:** se detectaron registros sin patente
#   identificable, los cuales fueron descartados por no aportar
#   valor al análisis ni al nuevo sistema.
#
# - **Reincidencia:** el análisis de las 10 patentes más multadas
#   evidencia vehículos con alta frecuencia de infracciones, lo que
#   sugiere conductores habituales de las vías monitoreadas.
#
# - **Distribución horaria:** la mayoría de las infracciones se
#   concentra en determinadas franjas horarias, lo que permite
#   orientar los controles hacia esos momentos de mayor riesgo.
#
# - **Distribución mensual:** la cantidad de infracciones varía
#   entre meses, con picos que pueden correlacionarse con mayor
#   circulación vehicular en ciertos períodos del año.
#
# En síntesis, el dataset requirió un tratamiento exhaustivo antes
# de poder ser utilizado de forma confiable. Los datos depurados
# constituyen una base sólida para incorporar al nuevo sistema y
# para futuras etapas de análisis del comportamiento vial.
# Out:
# Appending to README.md
