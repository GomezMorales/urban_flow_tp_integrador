# %% [markdown]
# # Trabajo Práctico Integrador

# %% [markdown]
# ## Urban Flow

# %% [markdown]
# ## Completar los integrantes del grupo y el número de grupo:
#
# `Obtener el número de grupo de la pestaña del aula de "Trabajos Prácticos"`
#
# `Entrega 1 solo integrante del grupo`
#
# Grupo nro 44:
#
#
# * **Mariano Tejerina**
# * **Emiliano Quiroga**
# * **Leandro Bonifacio**
# * **Luis Gomez Morales**

# %% [markdown]
# ## Repositorio GITHUB
#
# Especificar en la siguiente línea cual es la url para acceder al repositorio del grupo.

# %% [markdown]
# [Link al repositorio](https://github.com/GomezMorales/urban_flow_tp_integrador/tree/Sprint_2)

# %% [markdown]
# ## Sprint 2

# %% [markdown]
# ## Consideraciones Generales e Importantes
#
# - Desarrollo base: Los puntos solicitados son la base del trabajo práctico. Es posible la ampliación sin restricciones del mismo.
#
# - Organización del Notebook:
#   - Agregar antes del ejercicio 01 una celda donde se importan todas librerías necesarias.
#
#   - Utilizar un título para cada celda y escribir cada funcionalidad en una celda con título. Tener en cuenta agrupar las funcionalidades afines.

# %% [markdown]
# ## Versionado y Trabajo en Equipo
#
# - Para el traceo se deben agregar 1 [secrets](https://drlee.io/how-to-use-secrets-in-google-colab-for-api-key-protection-a-guide-for-openai-huggingface-and-c1ec9e1277e0) para la utilización de github.
#   - GITHUB_TOKEN
#
# - La entrega puede entregarse en grupos de máximo 6 personas (mínimo 1 / máximo 6) y la defensa es individual. Los grupos deben mantenerse a lo largo del trabajo integrador.
#
# - Se debe considerar que es un trabajo en equipo y que cualquiera de los integrantes puede realizar modificaciones para cada día de trabajo.
#
# - Control de Versiones: Utilizar herramientas de versionado. Vincularlo por token a tu cuenta personal de versionado en la nube.
#
# - Colaboradores: Brindar acceso al repositorio a las siguientes cuentas:
#
#   - lcd-had141@ugr.edu.ar
#
#   - fpasinato@ugr.edu.ar
#
# - Changelog: Cada ejercicio/punto del trabajo práctico es considerado como un día distinto de trabajo. Debe quedar constancia en un archivo CHANGELOG.md de los cambios generados cada día.
#
# - Agregar una variable llamada desactivar_git_push que solamente me permita desactivar los "git push".
#
# - El archivo README.md debe contener el sprint en el que nos encontramos y debe contener:
#   - El objetivo.
#   - La introducción y el contexto del sprint de trabajo.

# %% [markdown]
# ## Criterios de evaluación
#
# - Funcionalidad:
#
#   - El código debe ejecutar sin errores al ejecutar "Ejecutar todo" (Ctrl+F9).
#
#   - Se debe implementar la totalidad de las funcionalidades solicitadas.
#
#   - La lógica del programa debe ser correcta y consistente.
#
#   - Utilización de librerías acorde a los problemas a resolver.
#
#   - Recordar antes de entregar de validar el notebook con los siguientes pasos. Ir al menú Runtine/Ejecutar -> Restart session and run all/Reiniciar la sessión y ejecutar todo
#
# - Claridad y organización:
#
#   - El código debe estar bien organizado y dividido.
#
#   - Utilizar diferentes celdas de código para resolver cada solicitud/punto dentro de un ejercicio específico con su comentario "title" correspondiente a la solución implementada.
#
#   - Se deben utilizar nombres de variables que describan su contenido/función.
#
#   - Se debe agregar comentarios explicativos y necesarios según estandares.
#
#   - Todos los imports deben ubicarse en la primer celda de ejecución arriba de la descripción del "Ejercicio 01".
#
#   - No se admite la sentencia "git add ." para simplificar el traceo.
#
#   - No se admiten comentarios innecesarios dentro del código. Solo comentar funciones, clases, métodos y propiedades de clase.
#
# - Estilo y presentación:
#
#   - Se debe usar una indentación consistente y un formato de código adecuado.
#
#   - Se deben evitar comentarios redundantes o irrelevantes.
#
#   - Se debe presentar el código de forma ordenada y profesional.
#
#   - Se debe utilizar [type hints](https://docs.python.org/3/library/typing.html).
#
#   - Se deben utilizar comentarios según el [pep8](https://peps.python.org/pep-0008/).
#
# - Herramientas:
#
#   - Utilizar principalmente librerías vistas durante la cursada. No se admiten librerías similares a las vistas en la materia.
#
#   - Utilizar librerías extras con criterios fundamentados, es decir, no utilizar por utilizar.
#
#   - Indentar a 2 espacios y cortar a 80 caracteres según estandares.
#
#   - No se puede utilizar gdrive.
#
#   - No se pueden utilizar herramientas alternativas a las vistas durante la cursada.

# %% [markdown]
# ## Condiciones de Entrega
# - Formato de Archivo: Los estudiantes deberán enviar un archivo con extensión .ipynb.
#
# - Nomenclatura: El nombre original del archivo debe reemplazar los valores indicados. Ejemplo: 0X_Price_Manager-Grupo_X.ipynb.
#
# - Estado de la entrega:
#   - Deberá entregarse ejecutado y con los datos precargados.
#   - Deberá entregarse el desarrollo sobre una copia de la plantilla original.
#
# - Canal de Entrega: La entrega se realiza en el aula virtual y solo se aceptan archivos (cualquier otra forma se considerará inválida). Solo se recibirán trabajos por correo adjunto a lcd-had141@ugr.edu.ar si el plazo en la plataforma ha finalizado. No se aceptarán enlaces sueltos.

# %% [markdown]
# ## Recomendaciones y Consecuencias del Incumplimiento
# - Recomendaciones: Comenzar a trabajar con suficiente antelación. Leer y comprender el enunciado en su totalidad. Realizar consultas ante dudas al correo: lcd-had141@ugr.edu.ar o fpasinato@ugr.edu.ar. La entrega en tiempo y forma es fundamental.
#
# - Incumplimiento: Los trabajos que no cumplan con los requisitos no serán tomados en cuenta como nota final. Solo serán corregidos y evaluados con nota para la devolución correspondiente. Se considera incumplimiento a:
#
#   - Entregas fuera de término.
#
#   - Trabajos que no se entreguen sobre la plantilla de trabajo estipulada.
#
#   - Trabajos que no se ejecuten completos (que contengan errores intermedios al dar "Ejecutar todo").

# %% [markdown]
# ---

# %% [markdown]
# ## Objetivo
#
# El objetivo principal de este proyecto es aplicar los conocimientos adquiridos en el tratamiento de imágenes, la programación limpia y clara.

# %% [markdown]
# ## Introducción y Contexto del problema

# %% [markdown]
# ### Sprint 1
#
# **Solo a modo descriptivo, ya se trabajo en el tp 1**
#
# > La localidad llamada Vaalserberg de Bélgica se encuentra en la zona fronteriza y limita con los paises de Países Bajos y Alemania. Esta localidad cuenta con un sistema de radares urbanos para la detección de infracciones por exceso de velocidad. Los registros históricos provienen de sistemas heredados, el cuál presenta errores de formato, faltante de datos generando registros inconsistentes en el nuevo sistema.
# >
# > Debemos analizar y depurar los datos de viejo sistema para obtener información relevante sobre las infracciones y de está forma en el futuro poder incorporar los datos al nuevo sistema sin inconsistencias.
# >
# > [Descarga dataset](www.google.com)
# >
# > El dataset contiene información histórica de multas por exceso de velocidad y presenta errores que deberán ser tratados para evitar inconsistencias.

# %% [markdown]
# ### Sprint 2
#
# **Desarrollar el sprint 2**
#
# #### Introducción y contexto del nuevo problema
#
# Los radares urbanos generan registros administrativos de multas de forma automática y las cámaras asociadas registran la evidencia visual que acompaña y valida de forma visual la infracción. Sin embargo se plantean los siguientes puntos a tener en consideración:
#
# - No todas las multas tienen una imagen asociada.
#
# - No todas las imágenes corresponden a una infracción.
#
# - Puede haber errores de detección.
#
# El objetivo actual es desarrollar un sistema que determine ¿Qué multas tienen evidencia visual válida?
#
# Para esto vamos a necesitar los siguientes dataset:
#
# - Dataset procesado en el sprint 1.
#
# - [Dataset de imágenes](https://github.com/HAD141/datasets/raw/refs/heads/main/TrabajosPracticos/urban_flow/urban_flow_plates.zip) https://github.com/HAD141/datasets/raw/refs/heads/main/TrabajosPracticos/urban_flow/urban_flow_plates.zip

# %%
# Título: Importación de librerías y configuración global
# %pip install pandas requests matplotlib seaborn easyocr

import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import json
import cv2
import random
import difflib
import re
import easyocr
import zipfile
from typing import List, Optional, Dict, Any
from datetime import date
from pathlib import Path



desactivar_git_push: bool = True

def configurar_git():
  """Configura el entorno de Git según el host (Colab o Local)."""
  if 'google.colab' in str(get_ipython()):
    # %cd /content
    from google.colab import userdata
    try:
      token = userdata.get('GITHUB_TOKEN')
      repo_url = f"https://{token}@github.com/GomezMorales/urban_flow_tp_integrador.git"
    except:
      repo_url = "https://github.com/GomezMorales/urban_flow_tp_integrador.git"

    repo_name = "urban_flow_tp_integrador"
    if not os.path.exists(repo_name):
      # !git clone -b Sprint_2 {repo_url}
      # !rm -f urban_flow_tp_integrador/CHANGELOG.md

    # %cd {repo_name}
    try:
        email = userdata.get('GITHUB_EMAIL')
        name = userdata.get('GITHUB_NAME')
        # !git config --global user.email {email}
        # !git config --global user.name {name}
    except Exception:
        pass


configurar_git()

print("Librerías cargadas exitosamente y configuración inicial completa.")
# Out:
# ...
# /content
# /content/urban_flow_tp_integrador
# Librerías cargadas exitosamente y configuración inicial completa.

# %%
URL_FINES: str = (
  "https://raw.githubusercontent.com/HAD141/datasets/refs/heads/main/"
  "TrabajosPracticos/urban_flow/speeding_fines.csv"
)
PATH_RAW: str = "urban_flow/data/raw/speeding_fines.csv"
PATH_INTERIM: str = "urban_flow/data/interim"

# %%
def registrar_avance(descripcion: str, archivos: List[str]):
  """Actualiza el CHANGELOG y realiza el commit por ejercicio."""
  fecha_hoy = date.today().isoformat()
  entrada = f"\n## {fecha_hoy} - {descripcion}\n"
  with open("CHANGELOG.md", "a") as f:
    f.write(entrada)

  archivos_a_subir = archivos + ["CHANGELOG.md"]
  for archivo in archivos_a_subir:
    if os.path.exists(archivo):
      # !git add {archivo}

  # !git commit -m "{descripcion}"

  if not desactivar_git_push:
    # !git push origin Sprint_2

# %% [markdown]
# ### Ejercicio 01
#
# > Puntos: 1
#
# Inicialización y configuración de la herramienta de versionado. Para esto
# vamos a clonar el repositorio del trabajo práctico 1.
#
# Vamos a trabajar sobre la rama llamada "Sprint_2" y debemos partir de la
# rama "Sprint_1".
#
# Descargar el dataset de imágenes, descomprimirlo y almacenarlo en el
# directorio `urban_flow/data/raw/imgs`.

# %%
# Definición de rutas
URL_IMAGES = "https://github.com/HAD141/datasets/raw/refs/heads/main/TrabajosPracticos/urban_flow/urban_flow_plates.zip"
PATH_RAW_IMGS = "urban_flow/data/raw/imgs"
ZIP_TEMP = "images_temp.zip"

os.makedirs(PATH_RAW_IMGS, exist_ok=True)

# Descarga y descompresión
if not os.listdir(PATH_RAW_IMGS):
    print("Descargando imágenes...")
    r = requests.get(URL_IMAGES)
    with open(ZIP_TEMP, 'wb') as f: f.write(r.content)
    with zipfile.ZipFile(ZIP_TEMP, 'r') as zip_ref: zip_ref.extractall(PATH_RAW_IMGS)
    os.remove(ZIP_TEMP)
else:
    print("Imágenes ya presentes en el directorio local.")

registrar_avance(
    "Ejercicio 01 - Descarga de imagenes y traceo de las mismas con git",
    [PATH_RAW_IMGS]
)

print("Proceso de descarga de imagenes y traceo completado.")
# Out:
# Imágenes ya presentes en el directorio local.
# [Sprint_2 b3e1bf5] Ejercicio 01 - Descarga de imagenes y traceo de las mismas con git
#  1 file changed, 2 insertions(+)
# Proceso de descarga de imagenes y traceo completado.

# %% [markdown]
# ### Ejercicio 02
#
# > Puntos: 2
#
# En este punto realizaremos verificaciones sobre el dataset de imágenes:
#
# - Listar todas las imágenes disponibles (no mostrar/no imprimir). Se debe
#   mostrar el nombre y su tamaño en kb.
#
# - Separar las imágenes en 2 grupos, "completes" y "plates" y contar cuántas
#   imágenes hay en cada grupo. Ayuda: calcular la resolución promedio. Al
#   trabajar con la información de las imágenes vamos a utilizar un diccionario
#   (denominado `group_images`) para almacenar información importante que podemos
#   utilizar más adelante.
#
# La salida es:
# ```
# El grupo 'plates' contiene XX imágenes.
# El grupo 'completes' contiene XX imágenes.
# ```
#
# El diccionario es (guardarlo en `urban_flow/data/interim/group_images.json`):
# ```
# group_images = {
#   'plates': [{
#     'filename': contiene solo el nombre del archivo y la extensión,
#     'width': contiene el ancho en pixeles,
#     'height': contiene el alto en pixeles,
#     'area': cálculo del área de la imagen,
#     'path': contiene el path completo de la imagen original,
#     'patent': va a contener la patente
#   }],
#   'completes': [{
#     'filename': contiene solo el nombre del archivo y la extensión,
#     'width': contiene el ancho en pixeles,
#     'height': contiene el alto en pixeles,
#     'area': cálculo del área de la imagen,
#     'path': contiene el path completo de la imagen original,
#     'patent': va a contener la patente
#   }],
# }
# ```
#
# - Desarrollar una función para mostrar 8 imágenes de forma aleatoria en forma
#   de tabla de 2 columnas y 4 filas. Debe mostrar 4 imágenes de cada grupo. Es
#   una función reutilizable. En este punto se deben mostrar las imágenes
#   originales. Cada imagen debe tener un ancho de 10 pulgadas y un alto de 8
#   pulgadas, se debe mostrar el nombre de la imagen.

# %%
os.makedirs(PATH_INTERIM, exist_ok=True)
JSON_PATH = os.path.join(PATH_INTERIM, "group_images.json")

group_images = {
    'plates': [],
    'completes': []
}

total_area = 0
image_count = 0
lista_imagenes_disponibles = []

for root, dirs, files in os.walk(PATH_RAW_IMGS):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            full_path = os.path.join(root, file)

            size_kb = os.path.getsize(full_path) / 1024

            lista_imagenes_disponibles.append({
                'nombre': file,
                'tamano_kb': round(size_kb, 2)
            })

            img = cv2.imread(full_path)
            if img is not None:
                height, width = img.shape[:2]
                total_area += (width * height)
                image_count += 1

area_promedio = total_area / image_count if image_count > 0 else 0

for root, dirs, files in os.walk(PATH_RAW_IMGS):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg', '.jp2')):
            full_path = os.path.join(root, file)

            img = cv2.imread(full_path)
            if img is not None:
                height, width = img.shape[:2]
                area_actual = width * height

                if area_actual < area_promedio:
                    grupo = 'plates'
                else:
                    grupo = 'completes'

                img_metadata = {
                    'filename': file,
                    'width': width,
                    'height': height,
                    'area': area_actual,
                    'path': os.path.abspath(full_path),
                    'patent': ''
                }

                group_images[grupo].append(img_metadata)

with open(JSON_PATH, 'w', encoding='utf-8') as f:
    json.dump(group_images, f, indent=4, ensure_ascii=False)

print(f"El grupo 'plates' contiene {len(group_images['plates'])} imágenes.")
print(f"El grupo 'completes' contiene {len(group_images['completes'])} imágenes.")
print("---------------------------------------")
print("--- LISTADO DE IMÁGENES DISPONIBLES ---")
for img in lista_imagenes_disponibles:
    print(f"Nombre: {img['nombre']} | Tamaño: {img['tamano_kb']:.2f} KB")
# Out:
# El grupo 'plates' contiene 89 imágenes.
# El grupo 'completes' contiene 19 imágenes.
# ---------------------------------------
# --- LISTADO DE IMÁGENES DISPONIBLES ---
# Nombre: 80e02a518ffe4cb2.jpg | Tamaño: 119.68 KB
# Nombre: 0f4bfc46402a9f52.jpg | Tamaño: 131.21 KB
# Nombre: 5fb888d79b551331.jpg | Tamaño: 181.84 KB
# Nombre: 11f80fda2c38011c.jpg | Tamaño: 91.16 KB
# Nombre: 7bcf6b4ec09f1ea7_patente.jpg | Tamaño: 9.26 KB
# Nombre: 9a795bbf4e94d630.jpg | Tamaño: 64.95 KB
# Nombre: 593e594137f374ab.jpg | Tamaño: 331.58 KB
# Nombre: d648b2ae1abc09f3_patente_2.jpg | Tamaño: 9.82 KB
# Nombre: 665cac5fd1cc2186_patente.jpg | Tamaño: 6.29 KB
# Nombre: 90596bf3313e72e3_patente.jpg | Tamaño: 2.49 KB
# Nombre: 19eba8ac64eed194_patente_1.jpg | Tamaño: 20.88 KB
# Nombre: 28e26a4eb646c67a_patente.jpg | Tamaño: 7.53 KB
# Nombre: a6e3b0b73220cd32_patente.jpg | Tamaño: 5.25 KB
# Nombre: a56e82026bb71ad5_patente.jpg | Tamaño: 10.91 KB
# Nombre: 28bd6c6b1050e055_patente.jpg | Tamaño: 9.50 KB
# ...

# %%
def mostrar_imagenes_aleatorias(diccionario_grupos: dict)):
    """
    Selecciona 4 imágenes aleatorias de 'plates' y 4 de 'completes'
    y las muestra en una cuadrícula de 2 columnas por 4 filas.
    Cada imagen individual se visualiza a 10 pulgadas de ancho por 8 de alto.
    """
    if len(diccionario_grupos['plates']) < 4 or len(diccionario_grupos['completes']) < 4:
        print("Error: Se requieren al menos 4 imágenes en cada grupo para realizar el muestreo.")
        return

    muestra_plates = random.sample(diccionario_grupos['plates'], 4)
    muestra_completes = random.sample(diccionario_grupos['completes'], 4)

    lista_final = muestra_plates + muestra_completes

    fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(20, 32))
    axes = axes.flatten()

    for i, info in enumerate(lista_final):
        img_bgr = cv2.imread(info['path'])

        if img_bgr is not None:
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            axes[i].imshow(img_rgb)
        else:
            axes[i].text(0.5, 0.5, "Error al cargar", ha='center', va='center')

        axes[i].set_title(info['filename'], fontsize=14, pad=10)

        axes[i].axis('off')

    plt.tight_layout()
    plt.show()
# Out:
#   File "/tmp/ipykernel_5561/1894763270.py", line 1
#     def mostrar_imagenes_aleatorias(diccionario_grupos: dict)):
#                                                              ^
# SyntaxError: unmatched ')'

# %%
mostrar_imagenes_aleatorias(group_images)

# %%
PATH_INTERIM_FILE = PATH_INTERIM + '/group_images.json'

registrar_avance(
  "Ejercicio 02 - Creación de diccionario con imagenes e info de cada una \n- Desarrollo funcion reutilizable para mostrar 8 imagenes aleatorias",
  [PATH_INTERIM_FILE]
)

# %% [markdown]
# ### Ejercicio 03
#
# > puntos: 2
#
# En este punto realizaremos un procesamiento de las imágenes, en cada punto se debe llamar a la función que muestra las imágenes trabajadas en el punto anterior.
#
# - Conversión a escala de grises de las imágenes originales y almacenarlas en `urban_flow/data/interim/imgs/03_01_gray_scale/plates` y `urban_flow/data/interim/imgs/03_01_gray_scale/completes`, según la clasificación del ejercicio 2.
#
# - Realizar un suavizado de las imágenes en escala de grises y almacenarlas en `urban_flow/data/interim/imgs/03_02_blur` según la clasificación del ejercicio 2.
#
# - Realizar una detección de bordes sobre las imágenes suavizadas para intentar detectar las patentes y almacenarlas en `urban_flow/data/interim/imgs/03_03_canny` según la clasificación del ejercicio 2.

# %%
# Título: Ejercicio 03 - Paso 1: Conversión a escala de grises
PATH_GRAY = "urban_flow/data/interim/imgs/03_01_gray_scale"

def procesar_grises(group_images: dict) -> dict:
  """Convierte las imágenes originales a escala de grises y las guarda."""
  group_gray = {'plates': [], 'completes': []}

  for grupo in ['plates', 'completes']:
    carpeta_salida = os.path.join(PATH_GRAY, grupo)
    os.makedirs(carpeta_salida, exist_ok=True)

    for img_info in group_images[grupo]:
      img_bgr = cv2.imread(img_info['path'])

      if img_bgr is None:
        print(f"No se pudo leer: {img_info['path']}")
        continue

      img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
      ruta_salida = os.path.join(carpeta_salida, img_info['filename'])
      cv2.imwrite(ruta_salida, img_gray)
      group_gray[grupo].append(
        {**img_info, 'path': os.path.abspath(ruta_salida)}
      )
  return group_gray

group_gray = procesar_grises(group_images)
mostrar_imagenes_aleatorias(group_gray)

# %%
# Título: Ejercicio 03 - Paso 2: Suavizado de imágenes en escala de grises
PATH_BLUR = "urban_flow/data/interim/imgs/03_02_blur"

def procesar_blur(group_gray: dict) -> dict:
  """Aplica suavizado gaussiano a las imágenes en escala de grises."""
  group_blur = {'plates': [], 'completes': []}

  for grupo in ['plates', 'completes']:
    carpeta_salida = os.path.join(PATH_BLUR, grupo)
    os.makedirs(carpeta_salida, exist_ok=True)

    for img_info in group_gray[grupo]:
      img_gray = cv2.imread(img_info['path'], cv2.IMREAD_GRAYSCALE)

      if img_gray is None:
        print(f"No se pudo leer: {img_info['path']}")
        continue

      img_blur = cv2.GaussianBlur(img_gray, (5, 5), 0)
      ruta_salida = os.path.join(carpeta_salida, img_info['filename'])
      cv2.imwrite(ruta_salida, img_blur)
      group_blur[grupo].append(
        {**img_info, 'path': os.path.abspath(ruta_salida)}
      )
  return group_blur

group_blur = procesar_blur(group_gray)
mostrar_imagenes_aleatorias(group_blur)

# %%
# Título: Ejercicio 03 - Paso 3: Detección de bordes con Canny
PATH_CANNY = "urban_flow/data/interim/imgs/03_03_canny"

def procesar_canny(group_blur: dict) -> dict:
  """Aplica detección de bordes Canny a las imágenes suavizadas."""
  group_canny = {'plates': [], 'completes': []}

  for grupo in ['plates', 'completes']:
    carpeta_salida = os.path.join(PATH_CANNY, grupo)
    os.makedirs(carpeta_salida, exist_ok=True)

    for img_info in group_blur[grupo]:
      img_blur = cv2.imread(img_info['path'], cv2.IMREAD_GRAYSCALE)

      if img_blur is None:
        print(f"No se pudo leer: {img_info['path']}")
        continue

      img_canny = cv2.Canny(img_blur, 100, 200)
      ruta_salida = os.path.join(carpeta_salida, img_info['filename'])
      cv2.imwrite(ruta_salida, img_canny)
      group_canny[grupo].append(
        {**img_info, 'path': os.path.abspath(ruta_salida)}
      )
  return group_canny

group_canny = procesar_canny(group_blur)
mostrar_imagenes_aleatorias(group_canny)

# %%
registrar_avance(
  "Ejercicio 03 - Conversión a grises, suavizado y detección de bordes Canny",
  [PATH_GRAY, PATH_BLUR, PATH_CANNY]
)

# %%
# Título: Ejercicio 04 - Constantes del pipeline OCR
PATH_CANNY_PLATES: str = (
  "urban_flow/data/interim/imgs/03_03_canny/plates"
)
PATH_INTERIM_CSV: str = (
  "urban_flow/data/interim/speeding_fines.csv"
)
UMBRAL_SIMILITUD: float = 0.80
COL_PATENTE: str = "patente"

# %% [markdown]
# ### Ejercicio 04
#
# > puntos: 2
#
# Extracción de Información Visual de información.
#
# Vamos autilizar la función `extraer_patente` para obtener las patentes de las imágenes. Esta patente se almacena en la key `patent` del diccionario `group_images`.
#
# Una vez extraidas las patentes se debe relacionar lo extraido con el dataset previamente tratado y almacenado en `urban_flow/data/interim/speeding_fines.csv`, para finalmente guardar el dataset en `urban_flow/data/processed/speeding_fines_image.csv`.
#
# Para considerarlo como coincidencia se debe hacer un match de letras en orden de izquierda a derecha y el match debe ser del 80% o más.
#
# En caso de match se deben agregar las siguientes columnas al dataframe:
# - `imagen`: con el path a la imagen.
# - `patente_imagen`:  cual fue las letras obtenidas por el ocr.
# - `ratio`: el porcentaje de coincidencia.
#
#
# Ejemplos:
# | Patente Original | Patente Detectada | Match |
# | --- | --- | --- |
# | AL112PL | AI112BL | OK |
# | AL112PL | AL118BI | ERROR |
#
# `IMPORTANTE: Esta es una aproximación base y sin complicaciones.` Se aceptan otras exploraciones siempre y cuando los resultados sean aceptables. Una base un poco más compleja puede ser:
#  - Cierre Morfológico Rectangular: Usar un kernel rectangular horizontal para fusionar el contenido de la patente.
#  - Encontrar Contornos: Detectar las formas blancas resultantes del paso anterior.
#  - Filtrado Geométrico: Descartar los contornos que no parezcan una patente basándonos en:
#     - Área: Ni muy chica (ruido) ni muy grande (todo el auto).
#     - Relación de Aspecto (Aspect Ratio): Una patente es siempre más ancha que alta. La relación ancho / alto suele estar entre 2 y 5.
#     - Forma: Intentar aproximar el contorno a un polígono de 4 lados.
#
# `No se otorgan puntos extras por una exploración más compleja, pero si será tomado como nota de concepto para la puntuación final del cuatrimestre`

# %%
# Título: Ejercicio 04 - Funciones modulares del pipeline OCR


def listar_imagenes(carpeta: str) -> List[Path]:
  """
  Lista de forma eficiente las imágenes de una carpeta.

  Usa pathlib para iterar el directorio y filtra solo
  archivos con extensiones de imagen válidas.

  Args:
    carpeta: Ruta a la carpeta de imágenes a escanear.

  Returns:
    Lista ordenada de objetos Path a imágenes válidas.
  """
  ruta = Path(carpeta)
  extensiones = {".jpg", ".jpeg", ".png"}
  return sorted([
    p for p in ruta.iterdir()
    if p.is_file() and p.suffix.lower() in extensiones
  ])


def inicializar_reader_ocr() -> easyocr.Reader:
  """
  Inicializa el Reader de EasyOCR para inglés y español.

  Se configura sin GPU para mayor compatibilidad en Colab.
  La inicialización descarga los modelos la primera vez.

  Returns:
    Instancia de easyocr.Reader lista para usar.
  """
  return easyocr.Reader(['en', 'es'], gpu=False)


def extraer_texto_imagen(
  reader: easyocr.Reader,
  ruta: Path,
) -> str:
  """
  Extrae el texto de una imagen de patente usando EasyOCR.

  Captura cualquier excepción para que el pipeline no se
  detenga si una imagen está corrupta o no tiene texto.

  Args:
    reader: Lector EasyOCR ya inicializado.
    ruta:   Ruta Path a la imagen a procesar.

  Returns:
    Texto detectado concatenado, o cadena vacía si falla.
  """
  try:
    resultados = reader.readtext(str(ruta))
    if not resultados:
      return ""
    return " ".join(item[1] for item in resultados)
  except Exception as e:
    print(f"  [ERROR] {ruta.name}: {e}")
    return ""


def limpiar_texto_ocr(texto: str) -> str:
  """
  Normaliza el string extraído por OCR.

  Convierte a mayúsculas y elimina todo carácter que no
  sea letra (A-Z) ni dígito (0-9), ya que el ruido de la
  imagen Canny puede introducir símbolos extraños.

  Args:
    texto: String crudo devuelto por EasyOCR.

  Returns:
    String limpio: solo A-Z y 0-9 en mayúsculas.
  """
  texto = texto.upper()
  return re.sub(r'[^A-Z0-9]', '', texto)


def calcular_similitud(cadena_a: str, cadena_b: str) -> float:
  """
  Calcula el porcentaje de similitud entre dos strings.

  Usa difflib.SequenceMatcher, que encuentra los bloques
  de caracteres coincidentes más largos y aplica:

      ratio = 2 * M / T

  donde M = cantidad de caracteres en bloques coincidentes
        T = total de caracteres en ambas cadenas juntas.

  Ejemplos prácticos:
    - "ABC123" vs "ABC123" → ratio = 1.0  (idénticos)
    - "ABC123" vs "AB0123" → ratio ≈ 0.83 (1 char diff)
    - "ABC123" vs "XYZ999" → ratio ≈ 0.0  (sin match)

  El parámetro `isjunk=None` desactiva la heurística de
  autobasura, logrando mayor precisión en strings cortos
  como patentes donde cada carácter tiene peso relevante.

  Args:
    cadena_a: Primer string a comparar.
    cadena_b: Segundo string a comparar.

  Returns:
    Float en [0.0, 1.0]: 1.0 = idénticos, 0.0 = sin match.
  """
  if not cadena_a or not cadena_b:
    return 0.0
  matcher = difflib.SequenceMatcher(
    None, cadena_a, cadena_b
  )
  return matcher.ratio()


def buscar_mejor_coincidencia(
  texto_ocr: str,
  df: pd.DataFrame,
  col_patente: str = COL_PATENTE,
  umbral: float = UMBRAL_SIMILITUD,
) -> Dict[str, Any]:
  """
  Busca en el DataFrame la patente con mayor similitud
  al texto extraído por OCR.

  Itera todas las filas del DataFrame, normaliza cada
  patente (misma limpieza que el OCR) y calcula similitud.
  La fila con mayor similitud que supere el umbral
  determina si hay match exitoso.

  Args:
    texto_ocr:   Texto ya limpiado por limpiar_texto_ocr.
    df:          DataFrame de infracciones con patentes.
    col_patente: Nombre de la columna de patentes en df.
    umbral:      Similitud mínima para match (default 0.80).

  Returns:
    Dict con claves:
      match (bool): True si similitud >= umbral.
      similitud (float): Mejor similitud encontrada.
      patente_esperada (str|None): Patente del DataFrame.
      multa_id (int|None): ID de la multa coincidente.
  """
  mejor_similitud: float = 0.0
  mejor_fila: Optional[pd.Series] = None

  for _, fila in df.iterrows():
    patente_norm = re.sub(
      r'[^A-Z0-9]', '', str(fila[col_patente]).upper()
    )
    sim = calcular_similitud(texto_ocr, patente_norm)
    if sim > mejor_similitud:
      mejor_similitud = sim
      mejor_fila = fila

  return {
    "match": mejor_similitud >= umbral,
    "similitud": round(mejor_similitud, 4),
    "patente_esperada": (
      mejor_fila[col_patente]
      if mejor_fila is not None else None
    ),
    "multa_id": (
      int(mejor_fila["multa_id"])
      if mejor_fila is not None else None
    ),
  }


def procesar_ocr_pipeline(
  reader: easyocr.Reader,
  imagenes: List[Path],
  df: pd.DataFrame,
  umbral: float = UMBRAL_SIMILITUD,
) -> List[Dict[str, Any]]:
  """
  Ejecuta el pipeline OCR completo sobre las imágenes.

  Para cada imagen aplica en secuencia:
    1. Extracción de texto con EasyOCR.
    2. Limpieza del texto (mayúsculas, solo alfanumérico).
    3. Búsqueda del mejor match en el DataFrame.

  Args:
    reader:   Reader EasyOCR ya inicializado.
    imagenes: Lista de rutas Path a imágenes de patentes.
    df:       DataFrame con patentes reales esperadas.
    umbral:   Umbral mínimo de similitud para match.

  Returns:
    Lista de dicts con los resultados por imagen.
  """
  resultados: List[Dict[str, Any]] = []

  for ruta in imagenes:
    texto_crudo = extraer_texto_imagen(reader, ruta)
    texto_limpio = limpiar_texto_ocr(texto_crudo)
    resultado = buscar_mejor_coincidencia(
      texto_limpio, df, umbral=umbral
    )
    estado = "✓ MATCH" if resultado["match"] else "✗ ---  "
    print(
      f"  {ruta.name[:38]:<38} "
      f"OCR: {texto_limpio:<10} | {estado}"
    )
    resultados.append({
      "imagen": str(ruta),
      "texto_ocr_crudo": texto_crudo,
      "texto_ocr_limpio": texto_limpio,
      **resultado,
    })

  return resultados

# %%
# Título: Ejercicio 04 - Ejecución del pipeline OCR

df_interim: pd.DataFrame = pd.read_csv(PATH_INTERIM_CSV)

imagenes_canny: List[Path] = listar_imagenes(PATH_CANNY_PLATES)
print(
  f"Imágenes detectadas en carpeta Canny plates: "
  f"{len(imagenes_canny)}\n"
)

reader_ocr: easyocr.Reader = inicializar_reader_ocr()

resultados_ocr: List[Dict[str, Any]] = procesar_ocr_pipeline(
  reader_ocr,
  imagenes_canny,
  df_interim,
  umbral=UMBRAL_SIMILITUD,
)
print(f"\nPipeline finalizado. Imágenes procesadas: {len(resultados_ocr)}")

# %%
# Título: Ejercicio 04 - Integración al DataFrame y resumen

df_ocr_resultados: pd.DataFrame = pd.DataFrame(resultados_ocr)

df_matches: pd.DataFrame = (
  df_ocr_resultados[df_ocr_resultados["match"]]
  [["multa_id", "imagen", "texto_ocr_limpio", "similitud"]]
  .dropna(subset=["multa_id"])
  .astype({"multa_id": int})
  .drop_duplicates(subset=["multa_id"], keep="first")
)

df_procesado_final: pd.DataFrame = df_interim.merge(
  df_matches.rename(columns={
    "texto_ocr_limpio": "patente_imagen",
    "similitud": "ratio",
  }),
  on="multa_id",
  how="left",
)

try:
  ocr_por_imagen: Dict[str, Dict] = {
    Path(r["imagen"]).name: r for r in resultados_ocr
  }
  for img_info in group_canny["plates"]:
    nombre = img_info["filename"]
    if nombre in ocr_por_imagen:
      img_info["patent"] = (
        ocr_por_imagen[nombre]["texto_ocr_limpio"]
      )
  print("group_canny actualizado con patentes OCR.\n")
except NameError:
  print(
    "[AVISO] group_canny no está en memoria. "
    "Ejecutar celdas del Ejercicio 03 primero.\n"
  )

PATH_PROCESSED_CSV: str = (
  "urban_flow/data/processed/speeding_fines_image.csv"
)
df_procesado_final.to_csv(PATH_PROCESSED_CSV, index=False)

total_imgs: int = len(df_ocr_resultados)
total_match: int = int(df_ocr_resultados["match"].sum())
pct_exito: float = (
  total_match / total_imgs * 100 if total_imgs > 0 else 0.0
)

print("=" * 52)
print("  RESUMEN EJERCICIO 04 — OCR EasyOCR + Match 80%")
print("=" * 52)
print(f"  Imágenes procesadas    : {total_imgs}")
print(f"  Matches exitosos (≥80%): {total_match}")
print(f"  Porcentaje de éxito    : {pct_exito:.1f}%")
print("=" * 52)

print("\n--- Vista previa del DataFrame con OCR ---")
cols_vista: List[str] = [
  "multa_id", "patente", "imagen", "patente_imagen", "ratio"
]
print(
  df_procesado_final[cols_vista]
  .dropna(subset=["patente_imagen"])
  .head(10)
  .to_string(index=False)
)

# %%
# Título: Ejercicio 04 -  Actualizar group_images con las patentes extraídas y re-guardar el JSON
ocr_por_imagen_gimg: Dict[str, Dict] = {
    Path(r["imagen"]).name: r for r in resultados_ocr
}
for img_info in group_images["plates"]:
    nombre = img_info["filename"]
    if nombre in ocr_por_imagen_gimg:
        img_info["patent"] = ocr_por_imagen_gimg[nombre]["texto_ocr_limpio"]

# Re-guardar el JSON con las patentes completas
with open(JSON_PATH, 'w', encoding='utf-8') as f:
    json.dump(group_images, f, indent=4, ensure_ascii=False)

print("group_images actualizado y JSON re-guardado con patentes OCR.")

# %%
# Título: Ejercicio 04 - Versionado del ejercicio
registrar_avance(
  "Ejercicio 04 - OCR con EasyOCR, limpieza de texto "
  "y match de patentes al 80% con SequenceMatcher",
  [PATH_PROCESSED_CSV],
)

# %% [markdown]
# ### Ejercicio 05
#
# > puntos 2
#
# En este punto vamos a tomar algunas métricas del dataset final que se almacenó en el punto anterior.

# %% [markdown]
# - Mostrar la cantidad de multas sin imágenes según la columna `exceso_velocidad`.

# %%
print(df_procesado_final[df_procesado_final['imagen'].isna()]
    .groupby('exceso_velocidad')
    .size()
    .reset_index(name='cantidad'))

# %% [markdown]
# - Mostrar la cantidad de multas con imágenes según la columna `exceso_velocidad`.

# %%
print(df_procesado_final[df_procesado_final['imagen'].notna()]
    .groupby('exceso_velocidad')
    .size()
    .reset_index(name='cantidad'))

# %% [markdown]
# - Mostrar la cantidad de imágenes que no tuvieron match con el dataset.

# %%
imagenes_sin_match: int = len(df_ocr_resultados[~df_ocr_resultados['match']])
print(f"La cantidad de imágenes sin match son: {imagenes_sin_match}")

# %% [markdown]
# - Mostrar la cantidad de multas pendientes de pago.

# %%
cantidad_pendientes: int = len(df_procesado_final[
    df_procesado_final["estado_multa"] == "IMPAGA"])
print(f"La cantidad de multas pendientes de pago son: {cantidad_pendientes}")

# %% [markdown]
# - Mostrar la cantidad de multas pendientes de pago con imágenes relacionadas.

# %%
pendientes_con_imagen: int = len(df_procesado_final[
    (df_procesado_final['estado_multa'] == 'IMPAGA') &
    (df_procesado_final['imagen'].notna())])

print(f"La cantidad de multas pendientes de pago con imágenes relacionadas son: {pendientes_con_imagen}")

# %% [markdown]
# ### Ejercicio 06
#
# > puntos: 1
#
# Que podemos decir acerca de este tp en relación a las imágenes y los datos.

# %%
# %%writefile -a urban_flow/data/Readme.md
#
# # Conclusiones — Sprint 2
#
# ## Relación entre imágenes y datos
#
# El sistema analiza multas de Vaalserberg cruzando registros
# administrativos con evidencia visual obtenida por OCR sobre
# imágenes procesadas con filtro Canny.
#
# No todas las multas cuentan con imagen asociada, lo que
# refleja que no cada radar captura evidencia fotográfica
# utilizable en cada evento de infracción.
#
# La tasa de match del OCR sobre imágenes Canny es parcial:
# el preprocesamiento resalta bordes pero puede distorsionar
# caracteres (confusión entre 'O' y '0', 'I' y '1'), lo que
# limita la precisión del reconocimiento automático.
#
# De las multas en estado IMPAGA, solo una fracción cuenta
# con evidencia visual validada, lo que representa un desafío
# para su resolución administrativa o judicial.
#
# Una mejora futura consiste en aplicar cierre morfológico
# previo al OCR para fusionar regiones de texto en la patente,
# y filtrar contornos por relación de aspecto (ancho/alto
# entre 2 y 5), reduciendo el ruido antes del reconocimiento.

# %%
# Título: Ejercicio 06 - Versionado del ejercicio
registrar_avance(
  "Ejercicio 06 - Conclusiones sobre imágenes y datos",
  ["urban_flow/data/Readme.md"],
)

# %% [markdown]
# ## Visualizar la rama actual

# %%
# !git status

# %% [markdown]
# ## Visualizar el contenido de cada commit

# %%
# !git --no-pager log --name-status Sprint_2

# %% [markdown]
# ## Visualización de código

# %%
from IPython.display import display, HTML, Code
import os

display(HTML("""
<style>
  .jp-RenderedText pre, .jp-RenderedHTMLCommon pre, .p-Widget pre {
    background-color: #1e1e1e !important;
    color: #d4d4d4 !important;
    border: 1px solid #FFF !important;
  }
  .highlight  { background: #1e1e1e !important; }
  .highlight pre { border: 2px solid !important; }
</style>
"""))
#!rm -rf /content/sample_data .config

def visualizar_archivos_dark(directorio):
    for raiz, _, archivos in os.walk(directorio):
      if raiz.lower().endswith(('.git','.dvc', '__pycache__')):
        continue
      for nombre in archivos:
        if nombre.lower().endswith(('.py')):
          ruta = os.path.join(raiz, nombre)
          print(f"📁 {ruta}")
          with open(ruta, 'r') as f:
              contenido = f.read()
          display(Code(contenido, language=nombre.split('.')[-1]))
        if nombre.lower().endswith(('.md', '.csv')):
          ruta = os.path.join(raiz, nombre)
          print(f"📁 {ruta}")
          with open(ruta, 'r') as f:
              contenido = f.read()
          print("".join(contenido))
          print("\n\n")
          print("-" * 60)
          print("\n\n")

visualizar_archivos_dark('/content/')
